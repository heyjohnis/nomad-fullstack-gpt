# %%
from langchain.chat_models import ChatOpenAI
from langchain.document_loaders import UnstructuredFileLoader
from langchain.text_splitter import CharacterTextSplitter
from langchain.embeddings import OpenAIEmbeddings, CacheBackedEmbeddings
from langchain.vectorstores import FAISS
from langchain.storage import LocalFileStore
from langchain.prompts import ChatPromptTemplate
from langchain.schema.runnable import RunnablePassthrough, RunnableLambda

llm = ChatOpenAI(
    temperature=0.1,
)

cache_dir = LocalFileStore("./.cache/")

splitter = CharacterTextSplitter.from_tiktoken_encoder(
    separator="\n",
    chunk_size=600,
    chunk_overlap=100,
)
loader = UnstructuredFileLoader("./files/spirit.docx")

# %%
docs = loader.load_and_split(text_splitter=splitter)

embeddings = OpenAIEmbeddings()

cached_embeddings = CacheBackedEmbeddings.from_bytes_store(embeddings, cache_dir)

vectorstore = FAISS.from_documents(docs, cached_embeddings)

retriever = vectorstore.as_retriever()


map_doc_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            Use the following portion of a long document to see if any of the text is relevant to answer the question. Return any relevant text verbatim. If there is no relevant text, return : ''
            -------
            {context}
            """,
        ),
        ("human", "{question}"),
    ]
)

map_doc_chain = map_doc_prompt | llm


def map_docs(inputs):
    documents = inputs["documents"]
    question = inputs["question"]
    return "\n\n".join(
        map_doc_chain.invoke(
            {"context": doc.page_content, "question": question}
        ).content
        for doc in documents
    )


map_chain = {
    "documents": retriever,
    "question": RunnablePassthrough(),
} | RunnableLambda(map_docs)

final_prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """
            Given the following extracted parts of a long document and a question, create a final answer. 
            If you don't know the answer, just say that you don't know. Don't try to make up an answer.
            ------
            {context}
            """,
        ),
        ("human", "{question}"),
    ]
)

chain = {"context": map_chain, "question": RunnablePassthrough()} | final_prompt | llm

chain.invoke("성령은 언제 받는가요?")
# Out:
# Created a chunk of size 1164, which is longer than the specified 600
# Created a chunk of size 626, which is longer than the specified 600
# Created a chunk of size 681, which is longer than the specified 600
# Created a chunk of size 1154, which is longer than the specified 600
# Created a chunk of size 987, which is longer than the specified 600
# Created a chunk of size 865, which is longer than the specified 600
# Created a chunk of size 906, which is longer than the specified 600
# Created a chunk of size 1126, which is longer than the specified 600
# Created a chunk of size 855, which is longer than the specified 600
# Created a chunk of size 2104, which is longer than the specified 600
# Created a chunk of size 1629, which is longer than the specified 600
# Created a chunk of size 717, which is longer than the specified 600
# Created a chunk of size 637, which is longer than the specified 600
# Created a chunk of size 762, which is longer than the specified 600
# Created a chunk of size 1247, which is longer than the specified 600
# Created a chunk of size 1313, which is longer than the specified 600
# Created a chunk of size 851, which is longer than the specified 600
# Created a chunk of size 955, which is longer than the specified 600
# Created a chunk of size 800, which is longer than the specified 600
# Created a chunk of size 1055, which is longer than the specified 600
# Created a chunk of size 611, which is longer than the specified 600
# Created a chunk of size 1263, which is longer than the specified 600
# Created a chunk of size 625, which is longer than the specified 600
# Created a chunk of size 822, which is longer than the specified 600
# Created a chunk of size 1527, which is longer than the specified 600
# Created a chunk of size 623, which is longer than the specified 600
# Created a chunk of size 1473, which is longer than the specified 600
# Created a chunk of size 855, which is longer than the specified 600
# Created a chunk of size 831, which is longer than the specified 600
# Created a chunk of size 2278, which is longer than the specified 600
# Created a chunk of size 1365, which is longer than the specified 600
# Created a chunk of size 729, which is longer than the specified 600
# Created a chunk of size 1015, which is longer than the specified 600
# Created a chunk of size 1806, which is longer than the specified 600
# Created a chunk of size 768, which is longer than the specified 600
# Created a chunk of size 2017, which is longer than the specified 600
# Created a chunk of size 1210, which is longer than the specified 600
# Created a chunk of size 1100, which is longer than the specified 600
# Created a chunk of size 1362, which is longer than the specified 600
# Created a chunk of size 705, which is longer than the specified 600
# Created a chunk of size 1499, which is longer than the specified 600
# Created a chunk of size 1389, which is longer than the specified 600
# Created a chunk of size 816, which is longer than the specified 600
# Created a chunk of size 979, which is longer than the specified 600
# Created a chunk of size 636, which is longer than the specified 600
# Created a chunk of size 1537, which is longer than the specified 600
# Created a chunk of size 838, which is longer than the specified 600
# Created a chunk of size 661, which is longer than the specified 600
# Created a chunk of size 915, which is longer than the specified 600
# Created a chunk of size 728, which is longer than the specified 600
# Created a chunk of size 768, which is longer than the specified 600
# Created a chunk of size 746, which is longer than the specified 600
# Created a chunk of size 793, which is longer than the specified 600
# Created a chunk of size 883, which is longer than the specified 600
# Created a chunk of size 2575, which is longer than the specified 600
# Created a chunk of size 2444, which is longer than the specified 600
# Created a chunk of size 2281, which is longer than the specified 600
# Created a chunk of size 1792, which is longer than the specified 600
# Created a chunk of size 661, which is longer than the specified 600
# Created a chunk of size 623, which is longer than the specified 600
# Created a chunk of size 1274, which is longer than the specified 600
# Created a chunk of size 1300, which is longer than the specified 600
# Created a chunk of size 1057, which is longer than the specified 600
# Created a chunk of size 647, which is longer than the specified 600
# Created a chunk of size 973, which is longer than the specified 600
# Created a chunk of size 659, which is longer than the specified 600
# Created a chunk of size 712, which is longer than the specified 600
# Created a chunk of size 846, which is longer than the specified 600
# Created a chunk of size 1025, which is longer than the specified 600
# Created a chunk of size 1882, which is longer than the specified 600
# Created a chunk of size 1316, which is longer than the specified 600
# Created a chunk of size 1798, which is longer than the specified 600
# Created a chunk of size 795, which is longer than the specified 600
# Created a chunk of size 914, which is longer than the specified 600
# Created a chunk of size 733, which is longer than the specified 600
# Created a chunk of size 1091, which is longer than the specified 600
# Created a chunk of size 1310, which is longer than the specified 600
# Created a chunk of size 1447, which is longer than the specified 600
# Created a chunk of size 1055, which is longer than the specified 600
# Created a chunk of size 769, which is longer than the specified 600
# Created a chunk of size 1483, which is longer than the specified 600
# Created a chunk of size 822, which is longer than the specified 600
# Created a chunk of size 770, which is longer than the specified 600
# Created a chunk of size 641, which is longer than the specified 600
# Created a chunk of size 1055, which is longer than the specified 600
# Created a chunk of size 747, which is longer than the specified 600
# Created a chunk of size 601, which is longer than the specified 600
# Created a chunk of size 1738, which is longer than the specified 600
# Created a chunk of size 852, which is longer than the specified 600
# Created a chunk of size 746, which is longer than the specified 600
# Created a chunk of size 804, which is longer than the specified 600
# Created a chunk of size 603, which is longer than the specified 600
# Created a chunk of size 749, which is longer than the specified 600
# Created a chunk of size 614, which is longer than the specified 600
# Created a chunk of size 1082, which is longer than the specified 600
# Created a chunk of size 1606, which is longer than the specified 600
# Created a chunk of size 615, which is longer than the specified 600
# Created a chunk of size 886, which is longer than the specified 600
# Created a chunk of size 650, which is longer than the specified 600
# Created a chunk of size 1363, which is longer than the specified 600
# Created a chunk of size 776, which is longer than the specified 600
# Created a chunk of size 818, which is longer than the specified 600
# Created a chunk of size 728, which is longer than the specified 600
# Created a chunk of size 614, which is longer than the specified 600
# Created a chunk of size 609, which is longer than the specified 600
# Created a chunk of size 1101, which is longer than the specified 600
# Created a chunk of size 646, which is longer than the specified 600
# Created a chunk of size 609, which is longer than the specified 600
# Created a chunk of size 654, which is longer than the specified 600
# Created a chunk of size 807, which is longer than the specified 600
# Created a chunk of size 790, which is longer than the specified 600
# Created a chunk of size 661, which is longer than the specified 600
# Created a chunk of size 866, which is longer than the specified 600
# Created a chunk of size 1163, which is longer than the specified 600
# Created a chunk of size 1644, which is longer than the specified 600
# Created a chunk of size 669, which is longer than the specified 600
# Created a chunk of size 945, which is longer than the specified 600
# Created a chunk of size 942, which is longer than the specified 600
# Created a chunk of size 1047, which is longer than the specified 600
# Created a chunk of size 613, which is longer than the specified 600
# Created a chunk of size 676, which is longer than the specified 600
# Created a chunk of size 723, which is longer than the specified 600
# Created a chunk of size 611, which is longer than the specified 600
# Created a chunk of size 660, which is longer than the specified 600
# Created a chunk of size 1035, which is longer than the specified 600
# Created a chunk of size 768, which is longer than the specified 600
# Created a chunk of size 1066, which is longer than the specified 600
# Created a chunk of size 1446, which is longer than the specified 600
# Created a chunk of size 871, which is longer than the specified 600
# Created a chunk of size 1179, which is longer than the specified 600
# Created a chunk of size 727, which is longer than the specified 600
# Created a chunk of size 858, which is longer than the specified 600
# Created a chunk of size 632, which is longer than the specified 600
# Created a chunk of size 987, which is longer than the specified 600
# Created a chunk of size 620, which is longer than the specified 600
# Created a chunk of size 1114, which is longer than the specified 600
# Created a chunk of size 843, which is longer than the specified 600
# Created a chunk of size 769, which is longer than the specified 600
# Created a chunk of size 899, which is longer than the specified 600
# Created a chunk of size 609, which is longer than the specified 600
# Created a chunk of size 716, which is longer than the specified 600
# Created a chunk of size 809, which is longer than the specified 600
# Created a chunk of size 891, which is longer than the specified 600
# Created a chunk of size 853, which is longer than the specified 600
# Created a chunk of size 833, which is longer than the specified 600
# Created a chunk of size 775, which is longer than the specified 600
# Created a chunk of size 689, which is longer than the specified 600
# Created a chunk of size 613, which is longer than the specified 600
# Created a chunk of size 623, which is longer than the specified 600
# Created a chunk of size 965, which is longer than the specified 600
# Created a chunk of size 1594, which is longer than the specified 600
# Created a chunk of size 605, which is longer than the specified 600
# Created a chunk of size 1067, which is longer than the specified 600
# Created a chunk of size 711, which is longer than the specified 600
# Created a chunk of size 778, which is longer than the specified 600
# Created a chunk of size 1142, which is longer than the specified 600
# Created a chunk of size 693, which is longer than the specified 600
# Created a chunk of size 1355, which is longer than the specified 600
# Created a chunk of size 1783, which is longer than the specified 600
# Created a chunk of size 1297, which is longer than the specified 600
# Created a chunk of size 978, which is longer than the specified 600
# Created a chunk of size 982, which is longer than the specified 600
# Created a chunk of size 831, which is longer than the specified 600
# Created a chunk of size 809, which is longer than the specified 600
# Created a chunk of size 2004, which is longer than the specified 600
# Created a chunk of size 679, which is longer than the specified 600
# Created a chunk of size 676, which is longer than the specified 600
# Created a chunk of size 785, which is longer than the specified 600
# Created a chunk of size 671, which is longer than the specified 600
# Created a chunk of size 906, which is longer than the specified 600
# Created a chunk of size 866, which is longer than the specified 600
# Created a chunk of size 864, which is longer than the specified 600
# Created a chunk of size 1006, which is longer than the specified 600
# Created a chunk of size 605, which is longer than the specified 600
# Created a chunk of size 846, which is longer than the specified 600
# Created a chunk of size 790, which is longer than the specified 600
# Created a chunk of size 1118, which is longer than the specified 600
# Created a chunk of size 854, which is longer than the specified 600
# Created a chunk of size 669, which is longer than the specified 600
# Created a chunk of size 1515, which is longer than the specified 600
# Created a chunk of size 1017, which is longer than the specified 600
# Created a chunk of size 686, which is longer than the specified 600
# Created a chunk of size 645, which is longer than the specified 600
# Created a chunk of size 852, which is longer than the specified 600
# Created a chunk of size 907, which is longer than the specified 600
# Created a chunk of size 829, which is longer than the specified 600
# Created a chunk of size 748, which is longer than the specified 600
# Created a chunk of size 1033, which is longer than the specified 600
# Created a chunk of size 952, which is longer than the specified 600
# Created a chunk of size 1515, which is longer than the specified 600
# Created a chunk of size 1039, which is longer than the specified 600
# Created a chunk of size 946, which is longer than the specified 600
# Created a chunk of size 1022, which is longer than the specified 600
# Created a chunk of size 1072, which is longer than the specified 600
# Created a chunk of size 1226, which is longer than the specified 600
# Created a chunk of size 774, which is longer than the specified 600
# Created a chunk of size 694, which is longer than the specified 600
# Created a chunk of size 1950, which is longer than the specified 600
# Created a chunk of size 872, which is longer than the specified 600
# Created a chunk of size 920, which is longer than the specified 600
# Created a chunk of size 1164, which is longer than the specified 600
# Created a chunk of size 1181, which is longer than the specified 600
# Created a chunk of size 886, which is longer than the specified 600
# Created a chunk of size 1166, which is longer than the specified 600
# Created a chunk of size 1533, which is longer than the specified 600
# Created a chunk of size 793, which is longer than the specified 600
# Created a chunk of size 1270, which is longer than the specified 600
# Created a chunk of size 1761, which is longer than the specified 600
# Created a chunk of size 703, which is longer than the specified 600
# Created a chunk of size 663, which is longer than the specified 600
# Created a chunk of size 668, which is longer than the specified 600
# Created a chunk of size 803, which is longer than the specified 600
# Created a chunk of size 700, which is longer than the specified 600
# Created a chunk of size 637, which is longer than the specified 600
# Created a chunk of size 828, which is longer than the specified 600
# Created a chunk of size 976, which is longer than the specified 600
# Created a chunk of size 1823, which is longer than the specified 600
# Created a chunk of size 960, which is longer than the specified 600
# Created a chunk of size 998, which is longer than the specified 600
# Created a chunk of size 1701, which is longer than the specified 600
# Created a chunk of size 826, which is longer than the specified 600
# Created a chunk of size 1196, which is longer than the specified 600
# Created a chunk of size 1401, which is longer than the specified 600
# Created a chunk of size 644, which is longer than the specified 600
# Created a chunk of size 664, which is longer than the specified 600
# Created a chunk of size 1025, which is longer than the specified 600
# Created a chunk of size 835, which is longer than the specified 600
# Created a chunk of size 712, which is longer than the specified 600
# Created a chunk of size 1310, which is longer than the specified 600
# Created a chunk of size 859, which is longer than the specified 600
# Created a chunk of size 1157, which is longer than the specified 600
# Created a chunk of size 696, which is longer than the specified 600
# Created a chunk of size 677, which is longer than the specified 600
# Created a chunk of size 1749, which is longer than the specified 600
# Created a chunk of size 2049, which is longer than the specified 600
# Created a chunk of size 1211, which is longer than the specified 600
# Created a chunk of size 1704, which is longer than the specified 600
# Created a chunk of size 1177, which is longer than the specified 600
# Created a chunk of size 1684, which is longer than the specified 600
# Created a chunk of size 842, which is longer than the specified 600
# Created a chunk of size 1425, which is longer than the specified 600
# Created a chunk of size 830, which is longer than the specified 600
# Created a chunk of size 921, which is longer than the specified 600
# Created a chunk of size 2669, which is longer than the specified 600
# Created a chunk of size 2161, which is longer than the specified 600
# Created a chunk of size 1455, which is longer than the specified 600
# Created a chunk of size 1252, which is longer than the specified 600
# Created a chunk of size 791, which is longer than the specified 600
# Created a chunk of size 765, which is longer than the specified 600
# Created a chunk of size 947, which is longer than the specified 600
# Created a chunk of size 929, which is longer than the specified 600
# Created a chunk of size 820, which is longer than the specified 600
# Created a chunk of size 1764, which is longer than the specified 600
# Created a chunk of size 972, which is longer than the specified 600
# Created a chunk of size 898, which is longer than the specified 600
# Created a chunk of size 743, which is longer than the specified 600
# Created a chunk of size 648, which is longer than the specified 600
# Created a chunk of size 1245, which is longer than the specified 600
# Created a chunk of size 711, which is longer than the specified 600
# Created a chunk of size 1416, which is longer than the specified 600
# Created a chunk of size 1431, which is longer than the specified 600
# Created a chunk of size 645, which is longer than the specified 600
# Created a chunk of size 795, which is longer than the specified 600
# Created a chunk of size 633, which is longer than the specified 600
# Created a chunk of size 1774, which is longer than the specified 600
# Created a chunk of size 829, which is longer than the specified 600
# Created a chunk of size 1267, which is longer than the specified 600
# Created a chunk of size 694, which is longer than the specified 600
# Created a chunk of size 678, which is longer than the specified 600
# Created a chunk of size 1069, which is longer than the specified 600
# Created a chunk of size 2129, which is longer than the specified 600
# Created a chunk of size 855, which is longer than the specified 600
# Created a chunk of size 950, which is longer than the specified 600
# Created a chunk of size 946, which is longer than the specified 600
# Created a chunk of size 1029, which is longer than the specified 600
# Created a chunk of size 917, which is longer than the specified 600
# Created a chunk of size 2018, which is longer than the specified 600
# Created a chunk of size 1980, which is longer than the specified 600
# Created a chunk of size 955, which is longer than the specified 600
# Created a chunk of size 1449, which is longer than the specified 600
# Created a chunk of size 1036, which is longer than the specified 600
# Created a chunk of size 947, which is longer than the specified 600
# Created a chunk of size 1111, which is longer than the specified 600
# Created a chunk of size 1455, which is longer than the specified 600
# Created a chunk of size 2341, which is longer than the specified 600
# Created a chunk of size 1992, which is longer than the specified 600
# Created a chunk of size 1932, which is longer than the specified 600
# Created a chunk of size 670, which is longer than the specified 600
# Created a chunk of size 1018, which is longer than the specified 600
# Created a chunk of size 1032, which is longer than the specified 600
# Created a chunk of size 3237, which is longer than the specified 600
# Created a chunk of size 1377, which is longer than the specified 600
# Created a chunk of size 1353, which is longer than the specified 600
# Created a chunk of size 688, which is longer than the specified 600
# Created a chunk of size 1381, which is longer than the specified 600
# Created a chunk of size 1861, which is longer than the specified 600
# Created a chunk of size 1214, which is longer than the specified 600
# Created a chunk of size 913, which is longer than the specified 600
# Created a chunk of size 851, which is longer than the specified 600
# Created a chunk of size 961, which is longer than the specified 600
# Created a chunk of size 1802, which is longer than the specified 600
# Created a chunk of size 1195, which is longer than the specified 600
# Created a chunk of size 1423, which is longer than the specified 600
# Created a chunk of size 642, which is longer than the specified 600
# Created a chunk of size 647, which is longer than the specified 600
# Created a chunk of size 763, which is longer than the specified 600
# Created a chunk of size 632, which is longer than the specified 600
# Created a chunk of size 900, which is longer than the specified 600
# Created a chunk of size 818, which is longer than the specified 600
# Created a chunk of size 2206, which is longer than the specified 600
# Created a chunk of size 1201, which is longer than the specified 600
# Created a chunk of size 1691, which is longer than the specified 600
# Created a chunk of size 2033, which is longer than the specified 600
# Created a chunk of size 1171, which is longer than the specified 600
# Created a chunk of size 1554, which is longer than the specified 600
# Created a chunk of size 1189, which is longer than the specified 600
# Created a chunk of size 778, which is longer than the specified 600
# Created a chunk of size 1194, which is longer than the specified 600
# Created a chunk of size 830, which is longer than the specified 600
# Created a chunk of size 1135, which is longer than the specified 600
# Created a chunk of size 1313, which is longer than the specified 600
# Created a chunk of size 679, which is longer than the specified 600
# Created a chunk of size 1966, which is longer than the specified 600
# Created a chunk of size 827, which is longer than the specified 600
# Created a chunk of size 1462, which is longer than the specified 600
# Created a chunk of size 1696, which is longer than the specified 600
# Created a chunk of size 1779, which is longer than the specified 600
# Created a chunk of size 770, which is longer than the specified 600
# Created a chunk of size 689, which is longer than the specified 600
# Created a chunk of size 783, which is longer than the specified 600
# Created a chunk of size 1127, which is longer than the specified 600
# Created a chunk of size 1187, which is longer than the specified 600
# Created a chunk of size 1056, which is longer than the specified 600
# Created a chunk of size 914, which is longer than the specified 600
# Created a chunk of size 937, which is longer than the specified 600
# Created a chunk of size 1450, which is longer than the specified 600
# Created a chunk of size 1281, which is longer than the specified 600
# Created a chunk of size 1084, which is longer than the specified 600
# Created a chunk of size 671, which is longer than the specified 600
# Created a chunk of size 1007, which is longer than the specified 600
# Created a chunk of size 1451, which is longer than the specified 600
# Created a chunk of size 793, which is longer than the specified 600
# Created a chunk of size 1616, which is longer than the specified 600
# Created a chunk of size 1209, which is longer than the specified 600
# Created a chunk of size 1446, which is longer than the specified 600
# Created a chunk of size 1197, which is longer than the specified 600
# Created a chunk of size 644, which is longer than the specified 600
# Created a chunk of size 864, which is longer than the specified 600
# Created a chunk of size 783, which is longer than the specified 600
# Created a chunk of size 964, which is longer than the specified 600
# Created a chunk of size 1187, which is longer than the specified 600
# Created a chunk of size 857, which is longer than the specified 600
# Created a chunk of size 725, which is longer than the specified 600
# Created a chunk of size 855, which is longer than the specified 600
# Created a chunk of size 807, which is longer than the specified 600
# Created a chunk of size 2189, which is longer than the specified 600
# Created a chunk of size 1870, which is longer than the specified 600
# Created a chunk of size 1124, which is longer than the specified 600
# Created a chunk of size 1205, which is longer than the specified 600
# Created a chunk of size 1516, which is longer than the specified 600
# Created a chunk of size 1073, which is longer than the specified 600
# Created a chunk of size 1342, which is longer than the specified 600
# Created a chunk of size 2487, which is longer than the specified 600
# Created a chunk of size 1612, which is longer than the specified 600
# Created a chunk of size 675, which is longer than the specified 600
# Created a chunk of size 672, which is longer than the specified 600
# Created a chunk of size 1123, which is longer than the specified 600
# Created a chunk of size 1033, which is longer than the specified 600
# Created a chunk of size 1246, which is longer than the specified 600
# Created a chunk of size 1501, which is longer than the specified 600
# Created a chunk of size 961, which is longer than the specified 600
# Created a chunk of size 654, which is longer than the specified 600
# Created a chunk of size 1614, which is longer than the specified 600
# Created a chunk of size 687, which is longer than the specified 600
# Created a chunk of size 1138, which is longer than the specified 600
# Created a chunk of size 844, which is longer than the specified 600
# Created a chunk of size 999, which is longer than the specified 600
# Created a chunk of size 1712, which is longer than the specified 600
# Created a chunk of size 2025, which is longer than the specified 600
# Created a chunk of size 1007, which is longer than the specified 600
# Created a chunk of size 1384, which is longer than the specified 600
# Created a chunk of size 714, which is longer than the specified 600
# Created a chunk of size 2378, which is longer than the specified 600
# Created a chunk of size 1358, which is longer than the specified 600
# Created a chunk of size 1703, which is longer than the specified 600
# Created a chunk of size 2600, which is longer than the specified 600
# Created a chunk of size 1440, which is longer than the specified 600
# Created a chunk of size 2158, which is longer than the specified 600
# Created a chunk of size 782, which is longer than the specified 600
# Created a chunk of size 2102, which is longer than the specified 600
# Created a chunk of size 1059, which is longer than the specified 600
# Created a chunk of size 1556, which is longer than the specified 600
# Created a chunk of size 1151, which is longer than the specified 600
# Created a chunk of size 781, which is longer than the specified 600
# Created a chunk of size 817, which is longer than the specified 600
# Created a chunk of size 1315, which is longer than the specified 600
# Created a chunk of size 1335, which is longer than the specified 600
# Created a chunk of size 701, which is longer than the specified 600
# Created a chunk of size 1187, which is longer than the specified 600
# Created a chunk of size 2268, which is longer than the specified 600
# Created a chunk of size 1250, which is longer than the specified 600
# Created a chunk of size 1108, which is longer than the specified 600
# Created a chunk of size 915, which is longer than the specified 600
# Created a chunk of size 872, which is longer than the specified 600
# Created a chunk of size 1530, which is longer than the specified 600
# Created a chunk of size 1134, which is longer than the specified 600
# Created a chunk of size 1202, which is longer than the specified 600
# Created a chunk of size 900, which is longer than the specified 600
# Created a chunk of size 1068, which is longer than the specified 600
# Created a chunk of size 2055, which is longer than the specified 600
# Created a chunk of size 733, which is longer than the specified 600
# Created a chunk of size 1805, which is longer than the specified 600
# Created a chunk of size 2116, which is longer than the specified 600
# Created a chunk of size 1258, which is longer than the specified 600
# Created a chunk of size 1203, which is longer than the specified 600
# Created a chunk of size 941, which is longer than the specified 600
# Created a chunk of size 1918, which is longer than the specified 600
# Created a chunk of size 1988, which is longer than the specified 600
# Created a chunk of size 1745, which is longer than the specified 600
# Created a chunk of size 4608, which is longer than the specified 600
# Created a chunk of size 2021, which is longer than the specified 600
# Created a chunk of size 1859, which is longer than the specified 600
# Created a chunk of size 2666, which is longer than the specified 600
# Created a chunk of size 1130, which is longer than the specified 600
# Created a chunk of size 1158, which is longer than the specified 600
# Created a chunk of size 1041, which is longer than the specified 600
# Created a chunk of size 1310, which is longer than the specified 600
# Created a chunk of size 1490, which is longer than the specified 600
# Created a chunk of size 1082, which is longer than the specified 600
# Created a chunk of size 1724, which is longer than the specified 600
# Created a chunk of size 1232, which is longer than the specified 600
# Created a chunk of size 1107, which is longer than the specified 600
# Created a chunk of size 1646, which is longer than the specified 600
# Created a chunk of size 1329, which is longer than the specified 600
# Created a chunk of size 1175, which is longer than the specified 600
# Created a chunk of size 3039, which is longer than the specified 600
# Created a chunk of size 1561, which is longer than the specified 600
# Created a chunk of size 1926, which is longer than the specified 600
# Created a chunk of size 982, which is longer than the specified 600
# Created a chunk of size 1088, which is longer than the specified 600
# Created a chunk of size 877, which is longer than the specified 600
# Created a chunk of size 628, which is longer than the specified 600
# Created a chunk of size 781, which is longer than the specified 600
# Created a chunk of size 1454, which is longer than the specified 600
# Created a chunk of size 1939, which is longer than the specified 600
# Created a chunk of size 1490, which is longer than the specified 600
# Created a chunk of size 1640, which is longer than the specified 600
# Created a chunk of size 1424, which is longer than the specified 600
# Created a chunk of size 1705, which is longer than the specified 600
# Created a chunk of size 621, which is longer than the specified 600
# Created a chunk of size 887, which is longer than the specified 600
# Created a chunk of size 965, which is longer than the specified 600
# Created a chunk of size 640, which is longer than the specified 600
# Created a chunk of size 918, which is longer than the specified 600
# Created a chunk of size 664, which is longer than the specified 600
# Created a chunk of size 1209, which is longer than the specified 600
# Created a chunk of size 1227, which is longer than the specified 600
# Created a chunk of size 2087, which is longer than the specified 600
# Created a chunk of size 700, which is longer than the specified 600
# Created a chunk of size 1482, which is longer than the specified 600
# Created a chunk of size 1198, which is longer than the specified 600
# Created a chunk of size 725, which is longer than the specified 600
# Created a chunk of size 2007, which is longer than the specified 600
# Created a chunk of size 1917, which is longer than the specified 600
# Created a chunk of size 1513, which is longer than the specified 600
# Created a chunk of size 1412, which is longer than the specified 600
# Created a chunk of size 1281, which is longer than the specified 600
# Created a chunk of size 1431, which is longer than the specified 600
# Created a chunk of size 6127, which is longer than the specified 600
# Created a chunk of size 2001, which is longer than the specified 600
# Created a chunk of size 1469, which is longer than the specified 600
# Created a chunk of size 1297, which is longer than the specified 600
# Created a chunk of size 1209, which is longer than the specified 600
# Created a chunk of size 917, which is longer than the specified 600
# Created a chunk of size 1672, which is longer than the specified 600
# Created a chunk of size 906, which is longer than the specified 600
# Created a chunk of size 1182, which is longer than the specified 600
# Created a chunk of size 815, which is longer than the specified 600
# Created a chunk of size 1014, which is longer than the specified 600
# Created a chunk of size 1258, which is longer than the specified 600
# Created a chunk of size 1193, which is longer than the specified 600
# Created a chunk of size 1025, which is longer than the specified 600
# Created a chunk of size 720, which is longer than the specified 600
# Created a chunk of size 1215, which is longer than the specified 600
# Created a chunk of size 962, which is longer than the specified 600
# Created a chunk of size 939, which is longer than the specified 600
# Created a chunk of size 1322, which is longer than the specified 600
# Created a chunk of size 1163, which is longer than the specified 600
# Created a chunk of size 933, which is longer than the specified 600
# Created a chunk of size 809, which is longer than the specified 600
# Created a chunk of size 1133, which is longer than the specified 600
# Created a chunk of size 3572, which is longer than the specified 600
# Created a chunk of size 1230, which is longer than the specified 600
# Created a chunk of size 1663, which is longer than the specified 600
# Created a chunk of size 1062, which is longer than the specified 600
# Created a chunk of size 1195, which is longer than the specified 600
# Created a chunk of size 1259, which is longer than the specified 600
# Created a chunk of size 1946, which is longer than the specified 600
# Created a chunk of size 1534, which is longer than the specified 600
# Created a chunk of size 1427, which is longer than the specified 600
# Created a chunk of size 993, which is longer than the specified 600
# Created a chunk of size 4772, which is longer than the specified 600
# Created a chunk of size 1022, which is longer than the specified 600
# Created a chunk of size 5622, which is longer than the specified 600
# Created a chunk of size 673, which is longer than the specified 600
# Created a chunk of size 1448, which is longer than the specified 600
# Created a chunk of size 713, which is longer than the specified 600
# Created a chunk of size 891, which is longer than the specified 600
# Created a chunk of size 988, which is longer than the specified 600
# Created a chunk of size 2025, which is longer than the specified 600
# Created a chunk of size 1276, which is longer than the specified 600
# Created a chunk of size 947, which is longer than the specified 600
# Created a chunk of size 614, which is longer than the specified 600
# Created a chunk of size 774, which is longer than the specified 600
# Created a chunk of size 626, which is longer than the specified 600
# Created a chunk of size 777, which is longer than the specified 600
# Created a chunk of size 706, which is longer than the specified 600
# Created a chunk of size 914, which is longer than the specified 600
# Created a chunk of size 649, which is longer than the specified 600
# Created a chunk of size 1370, which is longer than the specified 600
# Created a chunk of size 1777, which is longer than the specified 600
# Created a chunk of size 1621, which is longer than the specified 600
# Created a chunk of size 1189, which is longer than the specified 600
# Created a chunk of size 1465, which is longer than the specified 600
# Created a chunk of size 1259, which is longer than the specified 600
# Created a chunk of size 740, which is longer than the specified 600
# Created a chunk of size 1268, which is longer than the specified 600
# Created a chunk of size 1160, which is longer than the specified 600
# Created a chunk of size 798, which is longer than the specified 600
# Created a chunk of size 915, which is longer than the specified 600
# Created a chunk of size 1598, which is longer than the specified 600
# Created a chunk of size 1328, which is longer than the specified 600
# Created a chunk of size 2099, which is longer than the specified 600
# Created a chunk of size 1519, which is longer than the specified 600
# Created a chunk of size 1103, which is longer than the specified 600
# Created a chunk of size 783, which is longer than the specified 600
# Created a chunk of size 700, which is longer than the specified 600
# Created a chunk of size 1485, which is longer than the specified 600
# Created a chunk of size 1327, which is longer than the specified 600
# Created a chunk of size 1477, which is longer than the specified 600
# Created a chunk of size 689, which is longer than the specified 600
# Created a chunk of size 1313, which is longer than the specified 600
# Created a chunk of size 935, which is longer than the specified 600
# Created a chunk of size 852, which is longer than the specified 600
# Created a chunk of size 971, which is longer than the specified 600
# Created a chunk of size 883, which is longer than the specified 600
# Created a chunk of size 1119, which is longer than the specified 600
# Created a chunk of size 1581, which is longer than the specified 600
# Created a chunk of size 1024, which is longer than the specified 600
# Created a chunk of size 1384, which is longer than the specified 600
# Created a chunk of size 700, which is longer than the specified 600
# Created a chunk of size 1323, which is longer than the specified 600
# Created a chunk of size 820, which is longer than the specified 600
# Created a chunk of size 1040, which is longer than the specified 600
# Created a chunk of size 1025, which is longer than the specified 600
# Created a chunk of size 787, which is longer than the specified 600
# Created a chunk of size 2742, which is longer than the specified 600
# Created a chunk of size 3825, which is longer than the specified 600
# Created a chunk of size 1392, which is longer than the specified 600
# Created a chunk of size 1137, which is longer than the specified 600
# Created a chunk of size 1312, which is longer than the specified 600
# Created a chunk of size 1621, which is longer than the specified 600
# Created a chunk of size 1384, which is longer than the specified 600
# Created a chunk of size 1572, which is longer than the specified 600
# Created a chunk of size 1359, which is longer than the specified 600
# Created a chunk of size 2118, which is longer than the specified 600
# Created a chunk of size 3546, which is longer than the specified 600
# Created a chunk of size 1667, which is longer than the specified 600
# Created a chunk of size 2725, which is longer than the specified 600
# Created a chunk of size 878, which is longer than the specified 600
# Created a chunk of size 1172, which is longer than the specified 600
# Created a chunk of size 1377, which is longer than the specified 600
# Created a chunk of size 2380, which is longer than the specified 600
# Created a chunk of size 1292, which is longer than the specified 600
# Created a chunk of size 742, which is longer than the specified 600
# Created a chunk of size 3050, which is longer than the specified 600
# Created a chunk of size 932, which is longer than the specified 600
# Created a chunk of size 873, which is longer than the specified 600
# Created a chunk of size 1285, which is longer than the specified 600
# Created a chunk of size 1263, which is longer than the specified 600
# Created a chunk of size 1473, which is longer than the specified 600
# Created a chunk of size 1481, which is longer than the specified 600
# Created a chunk of size 1960, which is longer than the specified 600
# Created a chunk of size 626, which is longer than the specified 600
# Created a chunk of size 1285, which is longer than the specified 600
# Created a chunk of size 1388, which is longer than the specified 600
# Created a chunk of size 1162, which is longer than the specified 600
# Created a chunk of size 925, which is longer than the specified 600
# Created a chunk of size 910, which is longer than the specified 600
# Created a chunk of size 1358, which is longer than the specified 600
# Created a chunk of size 682, which is longer than the specified 600
# Created a chunk of size 780, which is longer than the specified 600
# Created a chunk of size 1293, which is longer than the specified 600
# Created a chunk of size 1241, which is longer than the specified 600
# Created a chunk of size 662, which is longer than the specified 600
# Created a chunk of size 632, which is longer than the specified 600
# Created a chunk of size 1197, which is longer than the specified 600
# Created a chunk of size 962, which is longer than the specified 600
# Created a chunk of size 1534, which is longer than the specified 600
# Created a chunk of size 1735, which is longer than the specified 600
# Created a chunk of size 1391, which is longer than the specified 600
# Created a chunk of size 1820, which is longer than the specified 600
# Created a chunk of size 1713, which is longer than the specified 600
# Created a chunk of size 1128, which is longer than the specified 600
# Created a chunk of size 757, which is longer than the specified 600
# Created a chunk of size 1218, which is longer than the specified 600
# Created a chunk of size 967, which is longer than the specified 600
# Created a chunk of size 768, which is longer than the specified 600
# Created a chunk of size 1848, which is longer than the specified 600
# Created a chunk of size 1246, which is longer than the specified 600
# Created a chunk of size 1277, which is longer than the specified 600
# Created a chunk of size 2994, which is longer than the specified 600
# Created a chunk of size 1301, which is longer than the specified 600
# Created a chunk of size 800, which is longer than the specified 600
# Created a chunk of size 689, which is longer than the specified 600
# Created a chunk of size 1085, which is longer than the specified 600
# Created a chunk of size 656, which is longer than the specified 600
# Created a chunk of size 1076, which is longer than the specified 600
# Created a chunk of size 751, which is longer than the specified 600
# Created a chunk of size 1548, which is longer than the specified 600
# Created a chunk of size 1169, which is longer than the specified 600
# Created a chunk of size 1553, which is longer than the specified 600
# Created a chunk of size 1010, which is longer than the specified 600
# Created a chunk of size 1418, which is longer than the specified 600
# Created a chunk of size 1710, which is longer than the specified 600
# Created a chunk of size 705, which is longer than the specified 600
# Created a chunk of size 917, which is longer than the specified 600
# Created a chunk of size 1681, which is longer than the specified 600
# AIMessage(content="'성령을 받아야 한다’는 것은 아직 성령을 받지 않은 사람에게 주어지는 명령인데, 고린도전서 12장 13절의 내용은 이미 성령을 받은 사람에게 주신 말씀이다.")
